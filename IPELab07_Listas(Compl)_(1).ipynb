# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusMW21/Flexbox-CSS3/blob/master/IPELab07_Listas(Compl)_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SEQUÊNCIAS**
#
# Sequências são containers, um tipo de dado que contém outros dados. Existem três tipos básicos de sequência: **list** (lista), **tuple** (tupla) e **range** (objeto de intervalo). Outro tipo de sequência famoso que já vimos são as **strings**, que são sequências de texto.
#
# Sequências podem ser mutáveis ou imutáveis. Sequências imutáveis não podem ter seus valores modificados. Tuplas, strings e ranges são sequências imutáveis, enquanto listas são sequências mutáveis.
#
# **LISTAS**
#
# Uma das principais característica do Python são as listas. Uma Lista é uma sequência de valores onde cada valor é identificado por um índice iniciado por 0.
#
# São similares a strings (coleção de caracteres) exceto pelo fato de que os elementos de uma lista podem ser de qualquer tipo. No Python, listas substituem os arrays (vetores e matrizes).
#
# Sua sintaxe é simples, listas são delimitadas por colchetes e seus elementos separados por vírgula:
#
# **lista1 = [1, 2, 3, 4]**
#
# Listas não precisam necessariamente conter elementos de mesmo tipo; assim, podemos ter listas heterogêneas:
#
# **lista = [1, 2, 'python', 3.5, 'java']**
#
# Se queremos selecionar um elemento específico utilizamos o operador [ ] passando a posição, como se fosse para indicar um caractere de um string:
#
# Se queremos selecionar um elemento específico utilizamos o operador [ ] passando a posição, como se fosse para indicar um caractere de um string:
#
# **lista = [1, 2, 3, 4]**
#
# - lista[0] = 1
#
# - lista[1] = 2
#
# - lista[2] = 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Manipulação de Listas
# Inserção de elementos em uma lista (s indica o nome da lista):
#
# •	s.append(x): insere o elemento x ao final da lista s (apenas um elemento);
#
# •	s.extend([elementos]): insere o conjunto de elementos indicados ao final da lista s
#
# •	s.insert(posição, elementos): insere o conjunto de elementos indicados na posição indicada;
#
# •	del(s[x]): remove o elemento de posição x da lista s; os índices do elementos posteriores são readequados de acordo;
# •	s.clearQ: remove todos os elementos da lista s.
#
# *

# %% [markdown]
# Uma constante do tipo lista é escrita entre colchetes  com os elementos separados por vírgula:

# %%
[] # lista vazia
[1,2] # lista com 2 elementos
# Out:
# [1, 2]

# %% [markdown]
# Os elementos de uma lista podem ser de qualquer  tipo, inclusive listas. Ex.:

# %%
lista = [1, 'a', 2+3j, ['ab', 'CD']]

# %% [markdown]
# Os elementos de uma lista podem ser acessados por  índices como strings
# O primeiro elemento tem índice 0
# O último elemento tem índice ­1

# %%
lista = [1, 'a', 2+3j, ['ab', 'CD']]
# Out:
# [2, 'a', (2+3j), ['ab', 'CD']]

# %%
lista [0]

# %%
lista [2]

# %%
lista [3]

# %%
lista [-1]    #último elemento

# %%
lista [0] = 2
lista
# Out:
# [2, 'a', (2+3j), ['ab', 'CD']]

# %% [markdown]
# #Utilização de listas
#
# Para acessar (ler ou escrever) uma posição do vetor,  basta informar a posição entre colchetes

# %%
notas = [8.0, 5.5, 1.5]
for i in range(3):
  print(notas[i])
media = (notas[0] + notas[1] + notas[2]) / 3
# Out:
# 8.0
# 5.5
# 1.5

# %% [markdown]
# Exercícios
#
# 1)	Dada a lista = [12, -2, 4, 8, 29, 45, 78, 36, -17, 2,12, 8, 3, 3, -52] faça um programa que:
#
# a)	imprima o maior elemento
#
# b)	imprima o menor elemento
#
# c)	imprima os números pares
#
# d)	imprima o número de ocorrências do primeiro elemento da lista
#
# e)	imprima a média dos elementos
#
# f)	imprima a soma dos elementos de valor negativo

# %%
l1 = [12, -2, 4, 8, 29, -455, 199, 36, -17, 2,12, 8, 3, 353, -52] #lista principal
tam = len(l1) # definindo o tamanho da lista

def maior (l1):
  maior = 0
  for x in range(tam): # loop que percorre toda lista e vai armazenando o maior indice
    if l1[x] > maior:
      maior = l1[x]
  print (maior)
maior(l1)

def menor (l1):
  menor = 0
  for x in range(tam):
    if l1[x] == 0:
      menor = l1[x]
    elif l1[x] < menor:
      menor = l1[x]
  print(menor)
menor(l1)

def par(l1):
  


par(l1)
# Out:
# 353
# -455

# %% [markdown]
# 2)	1. Crie uma função que recebe um número N que indicará quantos valores naturais devem ser lidos (digitados) em seguida, e guardados em uma lista. Após a leitura dos valores inteiros, o programa mostra uma tabela contendo cada valor lido e o fatorial desse valor.

# %%
#Exercício 1

# %% [markdown]
# #A função list
#
# Pode ser usada para converter uma string numa lista
#
# É útil pois uma lista pode ser modificada, mas uma string, não
#
# Para fazer a transformação inversa, pode­se usar o método join

# %%
lista = list('alo')

# %%
lista

# %%
lista[1] = 'xx'

# %%
"".join(lista)

# %% [markdown]
# Concatenar duas listas

# %%
listal = [1, 2, 3, 4]
lista2 = [5, 6, 7]
for i in range(len(lista2)):
 listal.append(lista2[i])
print (listal)

# %% [markdown]
# Alternativa +

# %%
lista1 = [1, 2, 3, 4]
lista2 = [5, 6, 7]
lista1= lista1 + lista2
print (lista1)

# %% [markdown]
# Alternativa: método extend(lista2)

# %%
listal = [1, 2, 3, 4] 
lista2 = [5, 6, 7]
listal.extend(lista2) 
print(listal)

# %% [markdown]
# Len, min e max

# %%
lista = [1, 2, 9, 3, 4]

# %%
min (lista)

# %%
len (lista)

# %%
max (lista)

# %%
max (['a',	'b', 'c'])

# %% [markdown]
# Inserir um elemento em uma determinada  posição

# %%
lista = [1, 2, 3, 4] 
lista.insert (2, 10) 
print(lista)

# %% [markdown]
# Excluir um elemento

# %%
lista = [1, 2, 3, 4]  
lista.pop(2)  
print(lista)

# %% [markdown]
# A Classe list
#
# Uma lista é na verdade um objeto de uma classe chamada
# list
#
# Não vimos ainda programação OO, mas alguns pontos  devem ser enfatizados
# Listas possuem métodos que podem ser aplicados a elas
#
# Um método é semelhante a uma função, mas são  invocados de forma diferente: objeto.método(args)
#
# Ex.:	lista.reverse() inverte a ordem dos elementos  da lista

# %% [markdown]
# #Append(elemento)
#
# Acrescenta o elemento no fim da lista
#
# Observe que a operação altera a lista, e não  simplesmente
#
# retorna uma lista modificada

# %%
lista = [1,2]
lista.append(3)
lista

# %%
lista.append([4,5])
lista

# %% [markdown]
# #insert(indice, elemento)
#
# insere elemento na lista na posição indicada por índice

# %%
lista = [0,1,2,3]
lista.insert(1,'dois')
lista

# %% [markdown]
# #pop(índice)
#
# Remove da lista o elemento na posição índice e o retorna
#
# Se índice não for mencionado, é assumido o último
#
# Ex.:

# %%
lista = [1,2,3,4]
n=lista.pop()
print(n)
print(lista)

# %%
n=lista.pop(1)
print(n)
print(lista)

# %% [markdown]
# #remove(elemento)
#
# Remove da lista o primeiro elemento igual a elemento
#
# Se não existe tal elemento, um erro é gerado
#
# Ex.:

# %%
lista = ['oi', 'alo', 'ola']
lista.remove('alo')
lista

# %%
lista.remove('oba')

# %% [markdown]
# #reverse()
# Inverte a ordem dos elementos da lista
#
# Ex.:

# %%
lista=[1,2,3]
lista.reverse()
lista

# %% [markdown]
# #sort(cmp=None, key=None, reverse=False)
#
# Ordena a lista
#
# Os argumentos são opcionais. Por default, a lista é  ordenada crescentemente
#
# Ex.:

# %%
lista = [9,8,7,1,4,2]
lista.sort()
lista

# %% [markdown]
# #Listas: fatias (slices)
#
# A notação de fatias também pode ser usada, inclusive  para atribuição:

# %%
lista = [1, 'a', 2+3j, ['ab', 'CD']]
lista [1:]

# %%
lista [:1]

# %%
lista [1:2]

# %%
lista [0:-1]

# %% [markdown]
# #Listas: atribuição a fatias
#
# A atribuição a uma fatia requer que o valor atribuído seja uma seqüência  (uma lista ou uma string, por exemplo)
#
# A atribuição substitui os elementos da fatia pelos da seqüência

# %%
lista = [1, 'y', ['ab', 'CD']]
lista [1:1] = ['z']
lista

# %%
lista [1:3] = [['x']]
lista

# %%
lista [1:-1]= [2,3,4]
lista

# %%
lista [:2] = 'xyz'
lista

# %% [markdown]
# Exercícios

# %% [markdown]
# Transforme o exercício 2 em uma função para ler os números e retornar uma lista, e outra para mostrar o conteúdo de uma lista.

# %% [markdown]
# Conforme o exercicio 1b, transforme numa função e retorne a posição do menor valr

# %% [markdown]
# Insira as três funções no seguinte programa

# %%
v=leiamat()
for i in range(len(v)):
  posicao=pmenor(i:)+i
  if v[i]>v[posicao]:
    aux=v[i]
    v[i]=v[posicao]
    v[posicao]=aux
mostav(v)

# %% [markdown]
# Faça um programa para gerar o dígito verificador do CPF

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Faça um programa que imprima uma lista de múltiplos de três do 0 ao 300 (incluso)
def main():
  a = []
  for x in range(301):
    if (x % 3 == 0):
      a.append(x)
  print(a)
main()
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300]

# %%
#Crie um programa que, dado uma lista de números inteiros, verifique em qual posição desta lista está um valor entrado pelo usuário

l1 = [3, 7, 2, 1, 0, 32, 4, -2, 15, 30, 21, 73, 89, 12, 51]
print(l1)
num = int(input('Entre com o número a procurar na lista: '))
tam = len(l1)
x = 0
posic = -1
while (x < tam):
  if (l1[x] == num):
    posic = x
  x += 1

if (posic > -1):
  print('Número foi encontrado no índice ', posic)
else:
  print ('Número não foi encontrado.')
# Out:
# [3, 7, 2, 1, 0, 32, 4, -2, 15, 30, 21, 73, 89, 12, 51]
# Entre com o número a procurar na lista: -7
# Número não foi encontrado.
